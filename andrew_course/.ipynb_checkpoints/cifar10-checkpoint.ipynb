# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.metrics import error_rate

# %%
path = untar_data(URLs.CIFAR); path
# Out:
# PosixPath('/Users/mgbvox/.fastai/data/cifar10')

# %%
path.ls()
# Out:
# [PosixPath('/Users/mgbvox/.fastai/data/cifar10/test'),
#  PosixPath('/Users/mgbvox/.fastai/data/cifar10/models'),
#  PosixPath('/Users/mgbvox/.fastai/data/cifar10/labels.txt'),
#  PosixPath('/Users/mgbvox/.fastai/data/cifar10/train')]

# %%
path_anno = path/'labels.txt'
path_train = path/'train'
path_test = path/'test'

# %%
open(path_anno).readlines()
# Out:
# ['airplane\n',
#  'automobile\n',
#  'bird\n',
#  'cat\n',
#  'deer\n',
#  'dog\n',
#  'frog\n',
#  'horse\n',
#  'ship\n',
#  'truck\n']

# %%
path_train.ls()
# Out:
# [PosixPath('/Users/mgbvox/.fastai/data/cifar10/train/cat'),
#  PosixPath('/Users/mgbvox/.fastai/data/cifar10/train/dog'),
#  PosixPath('/Users/mgbvox/.fastai/data/cifar10/train/truck'),
#  PosixPath('/Users/mgbvox/.fastai/data/cifar10/train/bird'),
#  PosixPath('/Users/mgbvox/.fastai/data/cifar10/train/airplane'),
#  PosixPath('/Users/mgbvox/.fastai/data/cifar10/train/ship'),
#  PosixPath('/Users/mgbvox/.fastai/data/cifar10/train/frog'),
#  PosixPath('/Users/mgbvox/.fastai/data/cifar10/train/horse'),
#  PosixPath('/Users/mgbvox/.fastai/data/cifar10/train/deer'),
#  PosixPath('/Users/mgbvox/.fastai/data/cifar10/train/automobile')]

# %%
path_train.ls()[0].ls()[:10]
# Out:
# [PosixPath('/Users/mgbvox/.fastai/data/cifar10/train/cat/21851_cat.png'),
#  PosixPath('/Users/mgbvox/.fastai/data/cifar10/train/cat/45066_cat.png'),
#  PosixPath('/Users/mgbvox/.fastai/data/cifar10/train/cat/4835_cat.png'),
#  PosixPath('/Users/mgbvox/.fastai/data/cifar10/train/cat/35804_cat.png'),
#  PosixPath('/Users/mgbvox/.fastai/data/cifar10/train/cat/24696_cat.png'),
#  PosixPath('/Users/mgbvox/.fastai/data/cifar10/train/cat/3863_cat.png'),
#  PosixPath('/Users/mgbvox/.fastai/data/cifar10/train/cat/13822_cat.png'),
#  PosixPath('/Users/mgbvox/.fastai/data/cifar10/train/cat/45897_cat.png'),
#  PosixPath('/Users/mgbvox/.fastai/data/cifar10/train/cat/49197_cat.png'),
#  PosixPath('/Users/mgbvox/.fastai/data/cifar10/train/cat/13686_cat.png')]

# %%
data = ImageDataBunch.from_folder(path)
# Out:
# /Users/mgbvox/opt/anaconda3/envs/bao_ai/lib/python3.6/site-packages/fastai/data_block.py:457: UserWarning: Your validation set is empty. If this is by design, use `split_none()`
#                  or pass `ignore_empty=True` when labelling to remove this warning.
#   or pass `ignore_empty=True` when labelling to remove this warning.""")

# %%
data.show_batch()

# %%
data.classes
# Out:
# ['airplane',
#  'automobile',
#  'bird',
#  'cat',
#  'deer',
#  'dog',
#  'frog',
#  'horse',
#  'ship',
#  'truck']

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /Users/mgbvox/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# HBox(children=(FloatProgress(value=0.0, max=87306240.0), HTML(value='')))

# %%
learn.fit_one_cycle(4)
